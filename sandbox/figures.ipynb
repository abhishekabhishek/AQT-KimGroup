# %%
cd ..
# Out:
# /home/abhishekabhishek/git/AQT-KimGroup

# %%
import numpy as np
import fidelity

# %%
# Load the reconstructed DM from disk
data = 'ghz_6'
n_layers = 2
d_model = 128
n_epochs = 200
n_heads = 4
n_qubits = 6

#f_path = f'{data}/3_2700_{n_epochs}-{n_layers}-{d_model}-{n_heads}_dm.npy'
f_path = f'{data}/{n_qubits}_{(3**n_qubits)*100}_{n_epochs}-{n_layers}-{d_model}-{n_heads}_dm.npy'

# %%
# Load dm from disk
dm = np.load(f_path)


fidelity.plotDM(dm, n_qubits)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes3DSubplot: >)
